# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import statsmodels.formula.api as smf
from scipy.special import expit
from scipy.stats import logistic

# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv("2015_-_2016_Students_with_Multiple_Removals_or_Suspensions.csv")
df2 = pd.read_csv("2015-16_Multiple_Removals_-_Race.csv")
df3 = pd.read_csv("2015-16_Multiple_Removals_-_SWD.csv")
df4 = pd.read_csv("2015-16_Multiple_Removals_-_Year_of_Birth.csv")
df5 = pd.read_csv("2015-16_Multiple_Removals_-_Grade_Level.csv")
df6 = pd.read_csv("2015-16_Multiple_Removals_-_Gender.csv")

# %%
df1.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT  \
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
#
#   AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  *
# 4                                                  *
#
#   ASIAN STUDENTS With 2 or More Suspensions or Removals  \
# ...

# %%
df2.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT  \
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
#
#   AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  *
# 4                                                  *
#
#   ASIAN STUDENTS With 2 or More Suspensions or Removals  \
# ...

# %%
df6.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT  \
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
#
#   FEMALE STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  8
# 4                                                  *
#
#   MALE STUDENTS With 2 or More Suspensions or Removals  \
# ...

# %%
df3.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT  \
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
#
#   GEN ED STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  8
# 4                                                  *
#
#   SWD STUDENTS With 2 or More Suspensions or Removals  \
# ...

# %%
df4.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT 5 STUDENTS With 2 or More Suspensions or Removals  \
# 0                      1.0                                                 *
# 1                      1.0                                                 *
# 2                      1.0                                                 *
# 3                      1.0                                                 *
# 4                      1.0                                                 *
#
#   6 STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                 *
# ...

# %%
df5.head()
# Out:
#       DBN                   LOCATION NAME LOCATION CATEGORY  \
# 0  01M015       P.S. 015 Roberto Clemente        Elementary
# 1  01M019             P.S. 019 Asher Levy        Elementary
# 2  01M020            P.S. 020 Anna Silver        Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt               K-8
# 4  01M063       The STAR Academy - P.S.63        Elementary
#
#    ADMINISTRATIVE DISTRICT 0K STUDENTS With 2 or More Suspensions or Removals  \
# 0                      1.0                                                  *
# 1                      1.0                                                  *
# 2                      1.0                                                  *
# 3                      1.0                                                  *
# 4                      1.0                                                  *
#
#   01 STUDENTS With 2 or More Suspensions or Removals  \
# 0                                                  *
# ...

# %%
df1.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-1915fbb7ef2c> in <module>()
# ----> 1 df1.shape
#
# ~/.local/lib/python3.4/site-packages/dask/dataframe/core.py in __getattr__(self, key)
#    2436             return new_dd_object(merge(self.dask, dsk), name,
#    2437                                  meta, self.divisions)
# -> 2438         raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    2439
#    2440     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'shape'

# %%
# !pip install --user dask

# %%
# !pip install --user toolz

# %%
# !pip install --user cloudpickle

# %%
# !pip install --user methods

# %%
# !pip install --user "dask[complete]"

# %%
# kept getting errors until I restarted the kernel
#as per  https://github.com/dask/dask/issues/3348

# %%
import dask.dataframe as dd

# %%
# Read in the csv files.
#df1 = dd.read_csv('2015_-_2016_Students_with_Multiple_Removals_or_Suspensions.csv')
#df2 = dd.read_csv('2015-16_Multiple_Removals_-_Race.csv')


df1 = dd.read_csv("2015_-_2016_Students_with_Multiple_Removals_or_Suspensions.csv")
df2 = dd.read_csv("2015-16_Multiple_Removals_-_Race.csv")
df3 = dd.read_csv("2015-16_Multiple_Removals_-_SWD.csv")
df4 = dd.read_csv("2015-16_Multiple_Removals_-_Year_of_Birth.csv")
df5 = dd.read_csv("2015-16_Multiple_Removals_-_Grade_Level.csv")
df6 = dd.read_csv("2015-16_Multiple_Removals_-_Gender.csv")

# Merge the csv files.

#df = dd.merge(df1, df2, on='DBN').compute()

dff = dd.merge(dfe, df6, on='DBN').compute()


# Write the output.
dff.to_csv('school_suspensions_merged.csv', index=False)

# %%
suspensions = pd.read_csv("school_suspensions_merged.csv")
suspensions.head()
# Out:
#       DBN                 LOCATION NAME_x LOCATION CATEGORY_x  \
# 0  01M015       P.S. 015 Roberto Clemente          Elementary
# 1  01M019             P.S. 019 Asher Levy          Elementary
# 2  01M020            P.S. 020 Anna Silver          Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt                 K-8
# 4  01M063       The STAR Academy - P.S.63          Elementary
#
#    ADMINISTRATIVE DISTRICT_x  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
#
#   AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals_x  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  *
# 4                                                  *
#
# ...

# %%
suspensions.shape
# Out:
# (1743, 79)

# %%
suspensions.head()
# Out:
#       DBN                 LOCATION NAME_x LOCATION CATEGORY_x  \
# 0  01M015       P.S. 015 Roberto Clemente          Elementary
# 1  01M019             P.S. 019 Asher Levy          Elementary
# 2  01M020            P.S. 020 Anna Silver          Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt                 K-8
# 4  01M063       The STAR Academy - P.S.63          Elementary
#
#    ADMINISTRATIVE DISTRICT_x  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
#
#   AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals_x  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  *
# 4                                                  *
#
# ...

# %%
suspensionData = pd.read_csv("211516suspensions.csv")

# %%
suspensionData.head()
# Out:
#       DBN                 LOCATION NAME_x LOCATION CATEGORY_x  \
# 0  01M015       P.S. 015 Roberto Clemente          Elementary
# 1  01M019             P.S. 019 Asher Levy          Elementary
# 2  01M020            P.S. 020 Anna Silver          Elementary
# 3  01M034  P.S. 034 Franklin D. Roosevelt                 K-8
# 4  01M063       The STAR Academy - P.S.63          Elementary
#
#    ADMINISTRATIVE DISTRICT_x  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
#
#   AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals_x  \
# 0                                                  *
# 1                                                  *
# 2                                                  *
# 3                                                  *
# 4                                                  *
#
# ...

# %%
suspensionData.shape
# Out:
# (1743, 61)

# %%
suspensionData.describe()
# Out:
#        ADMINISTRATIVE DISTRICT_x
# count                1742.000000
# mean                   18.698622
# std                    15.639696
# min                     1.000000
# 25%                     9.000000
# 50%                    16.000000
# 75%                    26.000000
# max                    97.000000

# %%
suspensionData.dtypes
# Out:
# DBN                                                                                  object
# LOCATION NAME_x                                                                      object
# LOCATION CATEGORY_x                                                                  object
# ADMINISTRATIVE DISTRICT_x                                                           float64
# AMERICAN INDIAN/ALASKAN NATIVE STUDENTS With 2 or More Suspensions or Removals_x     object
# ASIAN STUDENTS With 2 or More Suspensions or Removals_x                              object
# BLACK STUDENTS With 2 or More Suspensions or Removals_x                              object
# HISPANIC STUDENTS With 2 or More Suspensions or Removals_x                           object
# WHITE STUDENTS With 2 or More Suspensions or Removals_x                              object
# MULTI-RACIAL STUDENTS With 2 or More Suspensions or Removals_x                       object
# ...
